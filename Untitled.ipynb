# %%
# %load_ext sql

# %%
# %sql sqlite:///grant.db
# Out:
# 'Connected: @grant.db'

# %%
# %%sql
# SELECT proposalID, applicationStatus
# FROM proposal
# Out:
#  * sqlite:///grant.db
# Done.
# [(0, 'Accepted'),
#  (1, 'Pending'),
#  (4, 'Pending'),
#  (5, 'Rejected'),
#  (6, 'Rejected'),
#  (7, 'Accepted'),
#  (8, 'Pending'),
#  (12, 'Accepted'),
#  (36, 'Accepted'),
#  (37, 'Rejected'),
#  (43, 'Rejected'),
#  (44, 'Pending'),
#  (46, 'Pending'),
#  (57, 'Rejected'),
#  (76, 'Accepted'),
#  (77, 'Accepted'),
#  (78, 'Accepted'),
#  (83, 'Pending'),
#  (92, 'Accepted'),
#  (425, 'Accepted'),
#  (704, 'Accepted'),
#  (952, 'Pending'),
#  (1975, 'Accepted'),
#  (2413, 'Accepted'),
#  (3284, 'Rejected'),
#  (6596, 'Pending'),
#  (7356, 'Rejected'),
#  (29829, 'Accepted'),
#  (50436, 'Rejected'),
#  (54658, 'Rejected'),
#  (66042, 'Rejected'),
#  (69006, 'Pending'),
#  (129557, 'Rejected'),
#  (328478, 'Rejected'),
#  (354413, 'Accepted'),
#  (462252, 'Accepted'),
#  (467285, 'Rejected'),
#  (486152, 'Rejected'),
#  (495241, 'Rejected'),
#  (514525, 'Rejected'),
#  (606414, 'Rejected'),
#  (913089, 'Accepted'),
#  (925129, 'Pending'),
# ...
